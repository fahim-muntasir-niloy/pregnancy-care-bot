# %%
from bs4 import BeautifulSoup
import requests

base_url = "https://shohay.health/pregnancy/"

r = requests.get(base_url)

# %%
r.content
# Out:
# b'<!doctype html>\n<html lang="bn-BD" class="no-js">\n\n<head>\n<!-- Required meta tags -->\n<meta charset="UTF-8">\n<meta name="viewport" content="width=device-width, initial-scale=1">\n<title>\xe0\xa6\x97\xe0\xa6\xb0\xe0\xa7\x8d\xe0\xa6\xad\xe0\xa6\xbe\xe0\xa6\xac\xe0\xa6\xb8\xe0\xa7\x8d\xe0\xa6\xa5\xe0\xa6\xbe &#8211; \xe0\xa6\xb8\xe0\xa6\xb9\xe0\xa6\xbe\xe0\xa7\x9f \xe0\xa6\xb9\xe0\xa7\x87\xe0\xa6\xb2\xe0\xa6\xa5</title><link rel="preload" as="font" href="https://assets.shohay.health/plugins/elementor/assets/lib/font-awesome/webfonts/fa-brands-400.woff2" crossorigin><link rel="preload" as="font" href="https://assets.shohay.health/plugins/elementor/assets/lib/font-awesome/webfonts/fa-solid-900.woff2" crossorigin><link rel="preload" as="font" href="https://assets.shohay.health/plugins/elementor/assets/lib/eicons/fonts/eicons.woff2?5.20.0" crossorigin><link rel="preload" as="font" href="https://fonts.gstatic.com/s/notoserifbengali/v19/hYkhPvggTvnzO14VSXltirUdnnkt1pwmWrprmO7RjE0a5BtdKyg8JCJZ.woff2" crossorigin><link rel="preload" as="font" href="https://fonts.gstatic.com/s/notoserifbengali/v19/hYkhPvggTvnzO14VSXltirUdnnkt1pwmWrprmO7RjE0a5BtdKzo8JA.woff2" crossorigin><style id="wpr-usedcss">:root{--bs-blue:#1565C0;--bs-indigo:#6610f2;--bs-purple:#6f42c1;--bs-pink:#d63384;--bs-red:#dc3545;--bs-orange:#fd7e14;--bs-yellow:#ffc107;--bs-green:#198754;--bs-teal:#20c997;--bs-cyan:#0dcaf0;--bs-white:#fff;--bs-gray:#555;--bs-gray-dark:#343a40;--bs-gray-100:#f8f9fa;--bs-gray-200:#f3f3f3;--bs-gray-300:#dee2e6;--bs-gray-400:#bebebe;--bs-gray-500:#767676;--bs-gray-600:#555;--bs-gray-700:#495057;--bs-gray-800:#343a40;--bs-gray-900:#212529;--bs-primary:#1565C0;--bs-secondary:#767676;--bs-success:#198754;--bs-info:#0dcaf0;--bs-warning:#ffc107;--bs-danger:#dc3545;--bs-light:#f8f9fa;--bs-dark:#212529;--bs-primary-rgb:21,101,192;--bs-secondary-rgb:118,118,118;--bs-success-rgb:25,135,84;--bs-info-rgb:13,202,240;--bs-warning-rgb:255,193,7;--bs-danger-rgb:220,53,69;--bs-light-rgb:248,249,250;--bs-dark-rgb:33,37,41;--bs-white-rgb:255,255,255;--bs-black-rgb:0,0,0;--bs-body-color-rgb:18,18,18;--bs-body-bg-rgb:255,255,255;--bs-font-sans-serif:system-ui,-apple-system,"Segoe UI",Roboto,"Helvetica Neue",Arial,"Noto Sans","Liberation Sans",sans-serif,"Apple Color Emoji","Segoe UI Emoji","Segoe UI Symbol","Noto Color Emoji";--bs-font-monospace:SFMono-Regular,Menlo,Monaco,Consolas,"Liberation Mono","Courier New",monospace;--bs-gradient:linear-gradient(180deg, rgba(255, 255, 255, .15), rgba(255, 255, 255, 0));--bs-body-font-family:var(--bs-font-sans-serif);--bs-body-font-size:1.14rem;--bs-body-font-weight:400;--bs-body-line-height:1.5;--bs-body-color:#121212;--bs-body-bg:#fff}*,::after,::before{box-sizing:border-box}@media(prefers-reduced-motion:no-preference){:root{scroll-behavior:smooth}}body{margin:0;font-family:var(--bs-body-font-family);font-size:var(--bs-body-font-size);font-weight:var(--bs-body-font-weight);line-height:var(--bs-body-line-height);color:var(--bs-body-color);text-align:var(--bs-body-text-align);background-color:var(--bs-body-bg);-webkit-text-size-adjust:100%;-webkit-tap-highlight-color:transparent}.h2,h1,h2,h3{margin-top:0;margin-bottom:.5rem;font-weight:700;line-height:1.2;color:#242424}h1{font-size:calc(1.3302rem + .9624vw)}@media(min-width:1200px){h1{font-size:2.052rem}}.h2,h2{font-size:calc(1.2789rem + .3468vw)}@media(min-width:1200px){.h2,h2{font-size:1.539rem}}h3{font-size:calc(1.2561rem + .0732vw)}@media(min-width:1200px){h3{font-size:1.311rem}}p{margin-top:0;margin-bottom:1rem}address{margin-bottom:1rem;font-style:normal;line-height:inherit}ol,ul{padding-left:2rem}dl,ol,ul{margin-top:0;margin-bottom:1rem}ol ol,ol ul,ul ol,ul ul{margin-bottom:0}dt{font-weight:700}b{font-weight:bolder}.small,small{font-size:.875em}.mark,mark{padding:.2em;background-color:#fcf8e3}a{color:#1565c0;text-decoration:none}a:hover{color:#11519a;text-decoration:underline}a:not([href]):not([class]),a:not([href]):not([class]):hover{color:inherit;text-decoration ...

# %%
url_list = [
    "first-week-of-pregnancy",
    "diet-and-nutrition/food-chart",
    # "symptoms",
    "week-by-week",
    "week-by-week/week-1-3",
    "week-by-week/week-4",
    "week-by-week/week-5",
    "week-by-week/week-6",
    "week-by-week/week-7",
    "week-by-week/week-8",
    "week-by-week/week-9",
    "week-by-week/week-10",
    "week-by-week/week-11",
    "week-by-week/week-12",
    "week-by-week/week-13",
    "week-by-week/week-14",
    "week-by-week/week-15",
    "week-by-week/week-16",
    "week-by-week/week-17",
    "week-by-week/week-18",
    "week-by-week/week-19",
    "week-by-week/week-20",
    "week-by-week/week-21",
    "week-by-week/week-22",
    "week-by-week/week-23",
    "week-by-week/week-24",
    "week-by-week/week-25",
    "week-by-week/week-26",
    "week-by-week/week-27",
    "week-by-week/week-28",
    "week-by-week/week-29",
    "week-by-week/week-30",
    "week-by-week/week-31",
    "week-by-week/week-32",
    "week-by-week/week-33",
    "week-by-week/week-34",
    "week-by-week/week-35",
    "week-by-week/week-36",
    "week-by-week/week-37",
    "week-by-week/week-38",
    "week-by-week/week-39",
    "week-by-week/week-40",
    "skin-rash-during-pregnancy",
    "snoring-during-pregnancy",
    "blurred-vision-during-pregnancy",
    "overheating-during-pregnancy",
    "pregnancy-brain",
    "clumsiness-during-pregnancy",
    "diarrhea-during-pregnancy",
    "stomach-tightening-during-pregnancy", 
]


more_urls = [
'https://shohay.health/pregnancy/danger-signs-of-pregnancy',
'https://shohay.health/pregnancy/labor-delivery/normal-delivery-increase-chances',
'https://shohay.health/pregnancy/labor-delivery/perineal-massage-before-delivery',
'https://shohay.health/pregnancy/miscarriage-stillbirth/miscarriage-symptoms-and-causes',
'https://shohay.health/pregnancy/miscarriage-stillbirth/miscarriage-afterwards',
'https://shohay.health/pregnancy/first-week-of-pregnancy',
'https://shohay.health/pregnancy/miscarriage-stillbirth/miscarriage-diagnosis',
'https://shohay.health/pregnancy/post-partum/physical-health-after-childbirth',
'https://shohay.health/pregnancy/week-by-week/week-41',
'https://shohay.health/pregnancy/symptoms/breech-presentation-of-the-baby',
'https://shohay.health/pregnancy/twins-and-multiple/twins-and-multiple-pregnancy',
'https://shohay.health/pregnancy/hormones',
'https://shohay.health/pregnancy/week-by-week/week-42',
'https://shohay.health/pregnancy/symptoms/polyhydramnios',
'https://shohay.health/pregnancy/symptoms',
'https://shohay.health/pregnancy/post-partum/contraceptives-after-delivery',
'https://shohay.health/pregnancy/miscarriage-stillbirth/miscarriage-faqs',
'https://shohay.health/pregnancy/miscarriage-stillbirth/miscarriage-treatment',
'https://shohay.health/pregnancy/tests/thyroid-function-test-in-pregnancy',
'https://shohay.health/pregnancy/post-partum/sex-after-delivery',
'https://shohay.health/pregnancy/diet-and-nutrition/food-chart',
'https://shohay.health/pregnancy/post-partum/recovery-after-delivery'
]

# %%
a = 'https://shohay.health/pregnancy/danger-signs-of-pregnancy'
a.split('/')
# Out:
# ['https:', '', 'shohay.health', 'pregnancy', 'danger-signs-of-pregnancy']

# %%
soup = BeautifulSoup(r.content, 'html.parser')

a_tags = []

for link in soup.find_all('a'):
    a_tags.append(link.get('href'))
    # print(set(a_tags))
    print(link.get('href'))
# Out:
# https://play.google.com/store/apps/details?id=health.shohay.pregnancy&referrer=utm_source%3DNotice%2520Bar%26utm_medium%3DWebsite%26utm_campaign%3DInternal%2520Referral
# https://shohay.health
# https://shohay.health/conditions
# https://shohay.health/sexual-health
# https://shohay.health/pregnancy
# https://shohay.health/topics/stomach-disorders
# https://shohay.health/wellness
# https://shohay.health/pregnancy/first-week-of-pregnancy
# https://shohay.health/pregnancy/first-week-of-pregnancy
# https://shohay.health/pregnancy/diet-and-nutrition/food-chart
# https://shohay.health/pregnancy/diet-and-nutrition/food-chart
# https://shohay.health/pregnancy/symptoms
# https://shohay.health/pregnancy/symptoms
# /pregnancy/week-by-week
# /pregnancy/week-by-week/week-1-3
# /pregnancy/week-by-week/week-4
# /pregnancy/week-by-week/week-5
# /pregnancy/week-by-week/week-6
# /pregnancy/week-by-week/week-7
# /pregnancy/week-by-week/week-8
# /pregnancy/week-by-week/week-9
# /pregnancy/week-by-week/week-10
# /pregnancy/week-by-week/week-11
# /pregnancy/week-by-week/week-12
# /pregnancy/week-by-week/week-13
# /pregnancy/week-by-week/week-14
# /pregnancy/week-by-week/week-15
# /pregnancy/week-by-week/week-16
# /pregnancy/week-by-week/week-17
# /pregnancy/week-by-week/week-18
# /pregnancy/week-by-week/week-19
# /pregnancy/week-by-week/week-20
# /pregnancy/week-by-week/week-21
# /pregnancy/week-by-week/week-22
# /pregnancy/week-by-week/week-23
# /pregnancy/week-by-week/week-24
# /pregnancy/week-by-week/week-25
# /pregnancy/week-by-week/week-26
# /pregnancy/week-by-week/week-27
# /pregnancy/week-by-week/week-28
# /pregnancy/week-by-week/week-29
# /pregnancy/week-by-week/week-30
# /pregnancy/week-by-week/week-31
# /pregnancy/week-by-week/week-32
# /pregnancy/week-by-week/week-33
# /pregnancy/week-by-week/week-34
# /pregnancy/week-by-week/week-35
# /pregnancy/week-by-week/week-36
# /pregnancy/week-by-week/week-37
# /pregnancy/week-by-week/week-38
# /pregnancy/week-by-week/week-39
# /pregnancy/week-by-week/week-40
# /tools/edd-calculator
# /pregnancy/symptoms
# https://shohay.health/conditions/skin-rash-during-pregnancy
# https://shohay.health/conditions/skin-rash-during-pregnancy
# https://shohay.health/conditions/snoring-during-pregnancy
# https://shohay.health/conditions/snoring-during-pregnancy
# https://shohay.health/conditions/blurred-vision-during-pregnancy
# https://shohay.health/conditions/blurred-vision-during-pregnancy
# https://shohay.health/conditions/overheating-during-pregnancy
# https://shohay.health/conditions/overheating-during-pregnancy
# https://shohay.health/conditions/pregnancy-brain
# https://shohay.health/conditions/pregnancy-brain
# https://shohay.health/conditions/clumsiness-during-pregnancy
# https://shohay.health/conditions/clumsiness-during-pregnancy
# https://shohay.health/conditions/diarrhea-during-pregnancy
# https://shohay.health/conditions/diarrhea-during-pregnancy
# https://shohay.health/conditions/stomach-tightening-during-pregnancy
# https://shohay.health/conditions/stomach-tightening-during-pregnancy
# /pregnancy/symptoms
# https://shohay.health/pregnancy/twins-and-multiple/twins-and-multiple-pregnancy
# https://shohay.health/pregnancy/twins-and-multiple/twins-and-multiple-pregnancy
# https://shohay.health/people/samia-afrin
# https://shohay.health/pregnancy/symptoms/polyhydramnios
# https://shohay.health/pregnancy/symptoms/polyhydramnios
# https://shohay.health/people/samia-afrin
# https://shohay.health/pregnancy/symptoms/breech-presentation-of-the-baby
# https://shohay.health/pregnancy/symptoms/breech-presentation-of-the-baby
# https://shohay.health/people/ima-islam
# https://shohay.health/pregnancy/post-partum/physical-health-after-childbirth
# https://shohay.health/pregnancy/post-partum/physical-health-after-childbirth
# https://shohay.health/people/samia-afrin
# https://shohay.health/pregnancy/tests/thyroid-function-test-in-pregnancy
# https://shohay.health/pregnancy/tests/thyroid-function-test-in-pregnancy
# https://shohay.health/people/samia-afrin
# https://shohay.health/pregnancy/miscarriage-stillbirth/miscarriage-faqs
# https://shohay.health/pregnancy/miscarriage-stillbirth/miscarriage-faqs
# https://shohay.health/people/senjuti-seemanta
# https://shohay.health/pregnancy/miscarriage-stillbirth/miscarriage-afterwards
# https://shohay.health/pregnancy/miscarriage-stillbirth/miscarriage-afterwards
# https://shohay.health/people/senjuti-seemanta
# https://shohay.health/pregnancy/miscarriage-stillbirth/miscarriage-treatment
# https://shohay.health/pregnancy/miscarriage-stillbirth/miscarriage-treatment
# https://shohay.health/people/senjuti-seemanta
# https://shohay.health/pregnancy/miscarriage-stillbirth/miscarriage-diagnosis
# https://shohay.health/pregnancy/miscarriage-stillbirth/miscarriage-diagnosis
# https://shohay.health/people/senjuti-seemanta
# https://shohay.health/pregnancy/miscarriage-stillbirth/miscarriage-symptoms-and-causes
# https://shohay.health/pregnancy/miscarriage-stillbirth/miscarriage-symptoms-and-causes
# https://shohay.health/people/senjuti-seemanta
# https://shohay.health/pregnancy/post-partum/contraceptives-after-delivery
# https://shohay.health/pregnancy/post-partum/contraceptives-after-delivery
# https://shohay.health/people/samia-afrin
# https://shohay.health/pregnancy/post-partum/sex-after-delivery
# https://shohay.health/pregnancy/post-partum/sex-after-delivery
# https://shohay.health/people/samia-afrin
# https://shohay.health/pregnancy/post-partum/recovery-after-delivery
# https://shohay.health/pregnancy/post-partum/recovery-after-delivery
# https://shohay.health/people/senjuti-seemanta
# https://shohay.health/pregnancy/labor-delivery/perineal-massage-before-delivery
# https://shohay.health/pregnancy/labor-delivery/perineal-massage-before-delivery
# https://shohay.health/people/ima-islam
# https://shohay.health/baby/breastfeeding/when-not-to-breastfeed
# https://shohay.health/baby/breastfeeding/when-not-to-breastfeed
# https://shohay.health/people/samia-afrin
# https://shohay.health/pregnancy/hormones
# https://shohay.health/pregnancy/hormones
# https://shohay.health/pregnancy/week-by-week/week-42
# https://shohay.health/pregnancy/week-by-week/week-42
# https://shohay.health/pregnancy/week-by-week/week-41
# https://shohay.health/pregnancy/week-by-week/week-41
# https://shohay.health/pregnancy/danger-signs-of-pregnancy
# https://shohay.health/pregnancy/danger-signs-of-pregnancy
# https://shohay.health/people/samia-afrin
# https://shohay.health/pregnancy/labor-delivery/normal-delivery-increase-chances
# https://shohay.health/pregnancy/labor-delivery/normal-delivery-increase-chances
# /about-us
# https://play.google.com/store/apps/details?id=health.shohay.pregnancy
# https://apps.apple.com/gb/app/shohay-pregnancy/id6478609582
# https://shohay.health/about-en
# https://shohay.health/careers
# https://shohay.health/disclaimer
# https://shohay.health/terms-of-use
# https://shohay.health/privacy-policy
# https://shohay.health/refund-policy
# https://www.facebook.com/ShohayHealth
# https://www.youtube.com/@ShohayHealth
# https://www.linkedin.com/company/shohay
# https://twitter.com/ShohayHealth
# #

# %%
for i in set(a_tags):
    try:
        if i.split('/')[3] == 'pregnancy':
            print(f"'{i}'")
    except:
        pass
# Out:
# 'https://shohay.health/pregnancy/danger-signs-of-pregnancy'
# 'https://shohay.health/pregnancy'
# 'https://shohay.health/pregnancy/labor-delivery/normal-delivery-increase-chances'
# 'https://shohay.health/pregnancy/labor-delivery/perineal-massage-before-delivery'
# 'https://shohay.health/pregnancy/miscarriage-stillbirth/miscarriage-symptoms-and-causes'
# 'https://shohay.health/pregnancy/miscarriage-stillbirth/miscarriage-afterwards'
# 'https://shohay.health/pregnancy/first-week-of-pregnancy'
# 'https://shohay.health/pregnancy/miscarriage-stillbirth/miscarriage-diagnosis'
# 'https://shohay.health/pregnancy/post-partum/physical-health-after-childbirth'
# 'https://shohay.health/pregnancy/week-by-week/week-41'
# 'https://shohay.health/pregnancy/symptoms/breech-presentation-of-the-baby'
# 'https://shohay.health/pregnancy/twins-and-multiple/twins-and-multiple-pregnancy'
# 'https://shohay.health/pregnancy/hormones'
# 'https://shohay.health/pregnancy/week-by-week/week-42'
# 'https://shohay.health/pregnancy/symptoms/polyhydramnios'
# 'https://shohay.health/pregnancy/symptoms'
# 'https://shohay.health/pregnancy/post-partum/contraceptives-after-delivery'
# 'https://shohay.health/pregnancy/miscarriage-stillbirth/miscarriage-faqs'
# 'https://shohay.health/pregnancy/miscarriage-stillbirth/miscarriage-treatment'
# 'https://shohay.health/pregnancy/tests/thyroid-function-test-in-pregnancy'
# 'https://shohay.health/pregnancy/post-partum/sex-after-delivery'
# 'https://shohay.health/pregnancy/diet-and-nutrition/food-chart'
# 'https://shohay.health/pregnancy/post-partum/recovery-after-delivery'

# %%
from html2text import html2text
import os

for url in url_list:
    u = os.path.join(base_url, url)
    html2text(u)
# Out:
# Text file saved as গর্ভবতী হওয়ার লক্ষণ.txt
# Text file saved as গর্ভবতী মায়ের খাবার তালিকা.txt
# Text file saved as গর্ভাবস্থায় সমস্যা ও করণীয়.txt
# Text file saved as সপ্তাহ অনুযায়ী গর্ভাবস্থা.txt
# Text file saved as গর্ভবতী হওয়ার লক্ষণ.txt
# Text file saved as গর্ভধারণের চতুর্থ সপ্তাহ.txt
# Text file saved as গর্ভধারণের পঞ্চম সপ্তাহ.txt
# Text file saved as গর্ভধারণের ষষ্ঠ সপ্তাহ.txt
# Text file saved as গর্ভধারণের সপ্তম সপ্তাহ.txt
# Text file saved as গর্ভধারণের অষ্টম সপ্তাহ.txt
# Text file saved as গর্ভধারণের নবম সপ্তাহ.txt
# Text file saved as গর্ভধারণের দশম সপ্তাহ.txt
# Text file saved as গর্ভধারণের ১১তম সপ্তাহ.txt
# Text file saved as গর্ভধারণের ১২তম সপ্তাহ.txt
# Text file saved as গর্ভধারণের ১৩তম সপ্তাহ.txt
# Text file saved as গর্ভধারণের ১৪তম সপ্তাহ.txt
# Text file saved as গর্ভধারণের ১৫তম সপ্তাহ.txt
# Text file saved as গর্ভধারণের ১৬তম সপ্তাহ.txt
# Text file saved as গর্ভধারণের ১৭তম সপ্তাহ.txt
# Text file saved as গর্ভধারণের ১৮তম সপ্তাহ.txt
# Text file saved as গর্ভধারণের ১৯তম সপ্তাহ.txt
# Text file saved as গর্ভধারণের ২০তম সপ্তাহ.txt
# Text file saved as গর্ভধারণের ২১তম সপ্তাহ.txt
# Text file saved as গর্ভধারণের ২২তম সপ্তাহ.txt
# Text file saved as গর্ভধারণের ২৩তম সপ্তাহ.txt
# Text file saved as গর্ভধারণের ২৪তম সপ্তাহ.txt
# Text file saved as গর্ভধারণের ২৫তম সপ্তাহ.txt
# Text file saved as গর্ভধারণের ২৬তম সপ্তাহ.txt
# Text file saved as গর্ভধারণের ২৭তম সপ্তাহ.txt
# Text file saved as গর্ভধারণের ২৮তম সপ্তাহ.txt
# Text file saved as গর্ভধারণের ২৯তম সপ্তাহ.txt
# Text file saved as গর্ভধারণের ৩০তম সপ্তাহ.txt
# Text file saved as গর্ভধারণের ৩১তম সপ্তাহ.txt
# Text file saved as গর্ভধারণের ৩২তম সপ্তাহ.txt
# Text file saved as গর্ভধারণের ৩৩তম সপ্তাহ.txt
# Text file saved as গর্ভধারণের ৩৪তম সপ্তাহ.txt
# Text file saved as গর্ভধারণের ৩৫তম সপ্তাহ.txt
# Text file saved as গর্ভধারণের ৩৬তম সপ্তাহ.txt
# Text file saved as গর্ভধারণের ৩৭তম সপ্তাহ.txt
# Text file saved as গর্ভধারণের ৩৮তম সপ্তাহ.txt
# Text file saved as গর্ভধারণের ৩৯তম সপ্তাহ.txt
# Text file saved as গর্ভধারণের ৪০তম সপ্তাহ.txt

# %%
for url in more_urls:
    html2text(url)
# Out:
# Text file saved as গর্ভাবস্থায় বিপদ চিহ্ন.txt
# Text file saved as নরমাল ডেলিভারির সম্ভাবনা বাড়াতে করণীয়.txt
# Text file saved as নরমাল ডেলিভারির ক্ষত এড়াতে পেরিনিয়াল ম্যাসাজ.txt
# Text file saved as গর্ভপাতের লক্ষণ ও কারণ.txt
# Text file saved as গর্ভপাত-পরবর্তী জীবন.txt
# Text file saved as গর্ভবতী হওয়ার লক্ষণ.txt
# Text file saved as গর্ভপাত নির্ণয়ের পরীক্ষা-নিরীক্ষা.txt
# Text file saved as প্রসব-পরবর্তী বিভিন্ন স্বাস্থ্য সমস্যার সমাধান.txt
# Text file saved as গর্ভধারণের ৪১তম সপ্তাহ.txt
# Text file saved as গর্ভে শিশুর অবস্থান—ব্রিচ পজিশন.txt
# Text file saved as যমজ এবং দুইয়ের অধিক গর্ভধারণ.txt
# Text file saved as গর্ভকালীন বিভিন্ন হরমোন ও এদের প্রভাব.txt
# Text file saved as গর্ভধারণের ৪২তম সপ্তাহ.txt
# Text file saved as পলিহাইড্রামনিওস বা গর্ভের পানি বেড়ে যাওয়া.txt
# Text file saved as গর্ভাবস্থায় সমস্যা ও করণীয়.txt
# Text file saved as প্রসব পরবর্তী জন্মনিয়ন্ত্রণ পদ্ধতি.txt
# Text file saved as গর্ভপাত নিয়ে প্রশ্ন-উত্তর.txt
# Text file saved as গর্ভপাতের চিকিৎসা.txt
# Text file saved as গর্ভাবস্থায় থাইরয়েড পরীক্ষা.txt
# Text file saved as সন্তান জন্মদানের পর সহবাস.txt
# Text file saved as গর্ভবতী মায়ের খাবার তালিকা.txt
# Text file saved as প্রসবের পর সেরে ওঠা.txt
